# %%
# Dependencies
import numpy as np
import datetime as dt
import pandas as pd
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
engine = create_engine("sqlite:///hawaii.sqlite")

# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
prev_year = dt.date(2017, 6, 23)

# %%
year = dt.date(2017, 12, 23)

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

#print(results.all())
#print(results)

# %% [markdown]
# ## D1: Determine the Summary Statistics for June

# %%
# 1. Import the sqlalchemy extract function.
#dt.timedelta(days-82 ==june 1)
from sqlalchemy import extract

year = dt.date(2017, 6, 23)

# %%
# 2. Write a query that filters the Measurement table to retrieve the temperatures for the month of June. 
results_june = session.query(Measurement.date, Measurement.tobs).filter(extract('month', Measurement.date)==6)
print(results_june.all())
# Out:
# [('2010-06-01', 78.0), ('2010-06-02', 76.0), ('2010-06-03', 78.0), ('2010-06-04', 76.0), ('2010-06-05', 77.0), ('2010-06-06', 78.0), ('2010-06-07', 77.0), ('2010-06-08', 78.0), ('2010-06-09', 78.0), ('2010-06-10', 79.0), ('2010-06-11', 78.0), ('2010-06-12', 78.0), ('2010-06-13', 78.0), ('2010-06-14', 77.0), ('2010-06-15', 78.0), ('2010-06-16', 78.0), ('2010-06-17', 77.0), ('2010-06-18', 77.0), ('2010-06-19', 82.0), ('2010-06-20', 78.0), ('2010-06-21', 78.0), ('2010-06-22', 78.0), ('2010-06-23', 78.0), ('2010-06-24', 78.0), ('2010-06-25', 77.0), ('2010-06-26', 76.0), ('2010-06-27', 78.0), ('2010-06-28', 78.0), ('2010-06-29', 78.0), ('2010-06-30', 78.0), ('2011-06-01', 77.0), ('2011-06-02', 78.0), ('2011-06-03', 73.0), ('2011-06-04', 70.0), ('2011-06-05', 76.0), ('2011-06-06', 77.0), ('2011-06-07', 77.0), ('2011-06-08', 77.0), ('2011-06-09', 77.0), ('2011-06-10', 78.0), ('2011-06-11', 77.0), ('2011-06-12', 77.0), ('2011-06-13', 78.0), ('2011-06-14', 78.0), ('2011-06-15', 77.0), ('2011-
# ...

# %%
#  3. 9.2.2 Convert the June temperatures to a list.
df = pd.DataFrame(results_june, columns=['date','temp'])
df.set_index(df['date'], inplace=True)
df = df.sort_index()
print (df)
# Out:
#                   date  temp
# date
# 2010-06-01  2010-06-01  78.0
# 2010-06-01  2010-06-01  73.0
# 2010-06-01  2010-06-01  77.0
# 2010-06-01  2010-06-01  69.0
# 2010-06-01  2010-06-01  76.0
# ...                ...   ...
# 2017-06-30  2017-06-30  76.0
# 2017-06-30  2017-06-30  75.0
# 2017-06-30  2017-06-30  75.0
# 2017-06-30  2017-06-30  74.0
# 2017-06-30  2017-06-30  75.0
#
# [1700 rows x 2 columns]

# %%
# 4. Create a DataFrame from the list of temperatures for the month of June. 
DataFrameJune = pd.DataFrame(results_june, columns=['date','temp'])
DataFrameJune
# Out:
#             date  temp
# 0     2010-12-01  76.0
# 1     2010-12-03  74.0
# 2     2010-12-04  74.0
# 3     2010-12-06  64.0
# 4     2010-12-07  64.0
# ...          ...   ...
# 1512  2016-12-27  71.0
# 1513  2016-12-28  71.0
# 1514  2016-12-29  69.0
# 1515  2016-12-30  65.0
# 1516  2016-12-31  65.0
#
# [1517 rows x 2 columns]

# %%
# 5. 9.2.5 Calculate and print out the summary statistics for the June temperature DataFrame.
DataFrameJune=DataFrameJune.sort_index()
print(DataFrameJune.to_string(index=False))
#print(results)
# Out:
#       date  temp
# 2010-12-01  76.0
# 2010-12-03  74.0
# 2010-12-04  74.0
# 2010-12-06  64.0
# 2010-12-07  64.0
# 2010-12-08  67.0
# 2010-12-09  77.0
# 2010-12-10  66.0
# 2010-12-11  69.0
# 2010-12-12  68.0
# 2010-12-13  68.0
# 2010-12-14  71.0
# 2010-12-15  74.0
# 2010-12-16  67.0
# 2010-12-17  66.0
# 2010-12-18  69.0
# 2010-12-19  71.0
# 2010-12-23  70.0
# 2010-12-24  70.0
# 2010-12-26  74.0
# 2010-12-27  74.0
# 2010-12-28  71.0
# 2010-12-29  75.0
# 2010-12-30  75.0
# 2010-12-31  72.0
# 2011-12-01  69.0
# 2011-12-02  68.0
# 2011-12-03  73.0
# 2011-12-04  74.0
# 2011-12-05  73.0
# 2011-12-06  73.0
# 2011-12-07  73.0
# 2011-12-08  73.0
# 2011-12-09  71.0
# 2011-12-10  73.0
# 2011-12-11  73.0
# 2011-12-12  77.0
# 2011-12-13  72.0
# 2011-12-14  71.0
# 2011-12-15  73.0
# 2011-12-16  70.0
# 2011-12-17  73.0
# 2011-12-18  69.0
# 2011-12-19  74.0
# 2011-12-20  72.0
# 2011-12-21  71.0
# 2011-12-22  72.0
# 2011-12-23  72.0
# 2011-12-24  70.0
# 2011-12-25  73.0
# 2011-12-26  73.0
# ...

# %%
DataFrameJune.plot()
# Out:
# <AxesSubplot:>

# %%
DataFrameJune.describe()
# Out:
#               temp
# count  1517.000000
# mean     71.041529
# std       3.745920
# min      56.000000
# 25%      69.000000
# 50%      71.000000
# 75%      74.000000
# max      83.000000

# %% [markdown]
# ## D2: Determine the Summary Statistics for December

# %%
# 1. Import the sqlalchemy extract function.
#dt.timedelta(days-82 ==june 1)
from sqlalchemy import extract

year = dt.date(2017, 12, 23) - dt.timedelta(days=60)

# %%
# 6. Write a query that filters the Measurement table to retrieve the temperatures for the month of December.
results_dec = session.query(Measurement.date, Measurement.tobs).filter(extract('month', Measurement.date)==12)

# %%
# 7. Convert the December temperatures to a list.
df = pd.DataFrame(results_dec, columns=['date','Temp'])
df.set_index(df['date'], inplace=True)
df = df.sort_index()
print (df)
# Out:
#                   date  Temp
# date
# 2010-12-01  2010-12-01  76.0
# 2010-12-01  2010-12-01  73.0
# 2010-12-01  2010-12-01  72.0
# 2010-12-01  2010-12-01  78.0
# 2010-12-01  2010-12-01  72.0
# ...                ...   ...
# 2016-12-31  2016-12-31  67.0
# 2016-12-31  2016-12-31  72.0
# 2016-12-31  2016-12-31  66.0
# 2016-12-31  2016-12-31  71.0
# 2016-12-31  2016-12-31  65.0
#
# [1517 rows x 2 columns]

# %%
# 8. Create a DataFrame from the list of temperatures for the month of December. 
DataFrameDec = pd.DataFrame(results_dec, columns=['date','temp'])
DataFrameDec
# Out:
#             date  temp
# 0     2010-12-01  76.0
# 1     2010-12-03  74.0
# 2     2010-12-04  74.0
# 3     2010-12-06  64.0
# 4     2010-12-07  64.0
# ...          ...   ...
# 1512  2016-12-27  71.0
# 1513  2016-12-28  71.0
# 1514  2016-12-29  69.0
# 1515  2016-12-30  65.0
# 1516  2016-12-31  65.0
#
# [1517 rows x 2 columns]

# %%
# 9. Calculate and print out the summary statistics for the Decemeber temperature DataFrame.
DataFrameDec.plot()
# Out:
# <AxesSubplot:>

# %%
DataFrameDec.describe()
# Out:
#               temp
# count  1517.000000
# mean     71.041529
# std       3.745920
# min      56.000000
# 25%      69.000000
# 50%      71.000000
# 75%      74.000000
# max      83.000000
